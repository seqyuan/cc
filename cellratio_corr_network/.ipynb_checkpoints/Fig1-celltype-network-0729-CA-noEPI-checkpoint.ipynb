# %% [markdown]
# # CA cell percentage corr

# %%
import pandas as pd
import glob
import networkx as nx
import numpy as np
import os
import seaborn as sns

import matplotlib.pyplot as plt

import matplotlib as mpl
mpl.rcParams['pdf.fonttype']=42
mpl.rcParams['ps.fonttype']=42

os.getcwd()
# Out:
# '/work/big_project/080/github/cellratio_corr_network'

# %%
df = pd.read_table('../data/Fig1_8type_73subcelltype_meta_new.csv', sep=",", index_col=0)
Tissue = 'CA'

df = df[df['Group'].isin(['CA'])]
df['cc'] = 1

df = df.groupby(['Sample', 'type', 'celltype']).sum()['cc'].reset_index()
df=df[~df['type'].isin(['Tumor', 'Epithelial'])]
df.head(2)
# Out:
# /tmp/ipykernel_978123/480343144.py:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = df.groupby(['Sample', 'type', 'celltype']).sum()['cc'].reset_index()
#    Sample   type   celltype  cc
# 0  CC12CA  Bcell      C1_Bn  10
# 1  CC12CA  Bcell  C2_Bn_MHC  38

# %%
df[df['celltype'].str.contains('C5')].query('type=="T_cell"')
# Out:
#      Sample    type    celltype  cc
# 47   CC12CA  T_cell  C5_CD4_Tfh  22
# 100  CC15CA  T_cell  C5_CD4_Tfh  21
# 163  CC19CA  T_cell  C5_CD4_Tfh  24
# 222   CC1CA  T_cell  C5_CD4_Tfh  20
# 284  CC21CA  T_cell  C5_CD4_Tfh  44
# 337  CC28CA  T_cell  C5_CD4_Tfh  59
# 399  CC34CA  T_cell  C5_CD4_Tfh  18
# 456  CC35CA  T_cell  C5_CD4_Tfh  16
# 506   CC3CA  T_cell  C5_CD4_Tfh   9
# 563   CC4CA  T_cell  C5_CD4_Tfh  65
# 624   CC5CA  T_cell  C5_CD4_Tfh  42
# 687   CC6CA  T_cell  C5_CD4_Tfh  30
# 750   CC7CA  T_cell  C5_CD4_Tfh   4
# 815   CC8CA  T_cell  C5_CD4_Tfh   5

# %%
df[df['celltype'].str.contains('C2')].query('type=="T_cell"')
# Out:
#      Sample    type         celltype   cc
# 44   CC12CA  T_cell  C2_CD4_Tem_IL7R   67
# 97   CC15CA  T_cell  C2_CD4_Tem_IL7R   20
# 160  CC19CA  T_cell  C2_CD4_Tem_IL7R   48
# 219   CC1CA  T_cell  C2_CD4_Tem_IL7R   37
# 281  CC21CA  T_cell  C2_CD4_Tem_IL7R  140
# 334  CC28CA  T_cell  C2_CD4_Tem_IL7R   35
# 396  CC34CA  T_cell  C2_CD4_Tem_IL7R   88
# 453  CC35CA  T_cell  C2_CD4_Tem_IL7R   69
# 503   CC3CA  T_cell  C2_CD4_Tem_IL7R   60
# 560   CC4CA  T_cell  C2_CD4_Tem_IL7R   96
# 621   CC5CA  T_cell  C2_CD4_Tem_IL7R  113
# 684   CC6CA  T_cell  C2_CD4_Tem_IL7R  104
# 747   CC7CA  T_cell  C2_CD4_Tem_IL7R   39
# 812   CC8CA  T_cell  C2_CD4_Tem_IL7R   65

# %%
#ax = sns.kdeplot(df['cc'])
#ax.set_title(f'{Tissue} celltype cell number density')

# %%
## 记录的是每个celltype 涉及的 样本数
df_celltype_sample = df[['Sample', 'celltype']].groupby(['celltype']).count()
#df_celltype_sample['Sample']

# %% [markdown]
# ## 以样本细胞总数为分母，去掉在少于一半样本出现的 细胞类型展示负相关性前10，正相关性取阈值

# %%
## 记录的是每个celltype 在每个sample里的细胞数
df_celltype_sample = df[['Sample', 'celltype']].groupby(['celltype']).count()
## 如果一个celltype 低于在一半样本中出现，则去除该细胞类型
df_celltype_sample['mean_rat'] =  df_celltype_sample['Sample']/len(df['Sample'].unique())

print(f'总细胞类型:{df_celltype_sample.shape[0]}')
#df_celltype_sample = df_celltype_sample.query('mean_rat>=0.5')
print(f'剩余细胞类型:{df_celltype_sample.shape[0]}')

df = df[df['celltype'].isin(df_celltype_sample.index)]
df.head(2)
# Out:
# 总细胞类型:59
# 剩余细胞类型:59
#    Sample   type   celltype  cc
# 0  CC12CA  Bcell      C1_Bn  10
# 1  CC12CA  Bcell  C2_Bn_MHC  38

# %%
df[df['celltype'].str.contains('C5')].query('type=="T_cell"')
# Out:
#      Sample    type    celltype  cc
# 47   CC12CA  T_cell  C5_CD4_Tfh  22
# 100  CC15CA  T_cell  C5_CD4_Tfh  21
# 163  CC19CA  T_cell  C5_CD4_Tfh  24
# 222   CC1CA  T_cell  C5_CD4_Tfh  20
# 284  CC21CA  T_cell  C5_CD4_Tfh  44
# 337  CC28CA  T_cell  C5_CD4_Tfh  59
# 399  CC34CA  T_cell  C5_CD4_Tfh  18
# 456  CC35CA  T_cell  C5_CD4_Tfh  16
# 506   CC3CA  T_cell  C5_CD4_Tfh   9
# 563   CC4CA  T_cell  C5_CD4_Tfh  65
# 624   CC5CA  T_cell  C5_CD4_Tfh  42
# 687   CC6CA  T_cell  C5_CD4_Tfh  30
# 750   CC7CA  T_cell  C5_CD4_Tfh   4
# 815   CC8CA  T_cell  C5_CD4_Tfh   5

# %%
df2 = df.groupby(['Sample']).sum()['cc']
df['sample_N'] = 0

for i in df.index:
    df.loc[i, "sample_N"] = df2[df.loc[i, "Sample"]]

df['ratio'] = df['cc']/df['sample_N']
# Out:
# /tmp/ipykernel_978123/2250543885.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2 = df.groupby(['Sample']).sum()['cc']

# %%
ratio_mat = df.pivot(index='Sample', columns='celltype', values='ratio')
ratio_mat = ratio_mat.fillna(0)
ratio_corr = ratio_mat.corr(method="pearson", min_periods=1, numeric_only=True)
ratio_mat.shape
# Out:
# (14, 59)

# %%
df4net = pd.DataFrame(np.triu(ratio_corr, k=1))
df4net.index = ratio_mat.columns
df4net.columns = ratio_mat.columns
df4net['idid'] = ratio_mat.columns
#del df4net['celltype']
df4net = df4net.melt(id_vars='idid')
df4net = df4net.query('value!=0')

ax = sns.kdeplot(df4net['value'])
#ax.axvline(0.4)
ax.set_title(f'{Tissue} cell fraction correlation distribution')
# Out:
# Text(0.5, 1.0, 'CA cell fraction correlation distribution')

# %%
h = sns.clustermap(ratio_corr, 
               figsize=(18, 18), 
               #col_colors=celltype_annotation[['celltype']],
               xticklabels=True,
               yticklabels=True,
               center=0,
               cbar_pos=(-0.1, 0.85, 0.03, 0.15), 
               dendrogram_ratio=0.1, 
               #square=True,
               cmap="bwr")

ax = plt.gca()


#h.savefig(f'0729/{Tissue}_{ratio_mat.shape[1]}celltype_{ratio_mat.shape[0]}sample_ratio_corr_heatmap_byType.pdf')

# %%
ratio_corr.index.name = None
ratio_corr.columns.name = None

# %%
df['type'].unique()
# Out:
# array(['Bcell', 'DC', 'Endothelial', 'Fibroblast', 'Myeloid', 'T_cell'],
#       dtype=object)

# %%
ccc = pd.DataFrame({'color': ['#438EC0', '#C3AAD2', '#F7A962',  '#7C53A4', '#97D277', '#E62E27']})
ccc.index = ['Bcell','DC','Endothelial','Fibroblast','Myeloid','T_cell']
display(ccc)

aaa = df.groupby(['type', 'celltype']).sum().reset_index()
aaa.index = aaa['celltype']
aaa['color'] = ccc.loc[aaa['type'], 'color'].to_list()
aaa.head(2)
# Out:
#                color
# Bcell        #438EC0
# DC           #C3AAD2
# Endothelial  #F7A962
# Fibroblast   #7C53A4
# Myeloid      #97D277
# T_cell       #E62E27
# /tmp/ipykernel_978123/279296463.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   aaa = df.groupby(['type', 'celltype']).sum().reset_index()
#             type   celltype   cc  sample_N     ratio    color
# celltype
# C1_Bn      Bcell      C1_Bn  371     43046  0.117032  #438EC0
# C2_Bn_MHC  Bcell  C2_Bn_MHC  917     43046  0.328357  #438EC0

# %%
aaa[aaa['celltype'].str.contains('C2')].query('type=="T_cell"')
# Out:
#                    type         celltype   cc  sample_N     ratio    color
# celltype
# C2_CD4_Tem_IL7R  T_cell  C2_CD4_Tem_IL7R  981     43046  0.331347  #E62E27

# %%
df4net.head(2)
# Out:
#                  idid     celltype     value
# 59   C10_CD8_Trm_GZMB  C10_Fib_HSP -0.237870
# 118  C10_CD8_Trm_GZMB  C11_CD8_Tex  0.659228

# %%
df4net.query('idid=="C2_CD4_Tem_IL7R" or celltype=="C2_CD4_Tem_IL7R"').describe()
# Out:
#            value
# count  58.000000
# mean    0.011285
# std     0.262055
# min    -0.387229
# 25%    -0.191032
# 50%    -0.044465
# 75%     0.211459
# max     0.697132

# %%
df4net.query('idid=="C5_CD4_Tfh" or celltype=="C5_CD4_Tfh"').describe()
# Out:
#            value
# count  58.000000
# mean   -0.082392
# std     0.280716
# min    -0.494570
# 25%    -0.342056
# 50%    -0.115910
# 75%     0.144364
# max     0.608195

# %%
df4net_tmp = df4net.copy()
df4net_tmp['weight_scale'] = abs(df4net_tmp['value'])
display(df4net_tmp.head(2))
#df4net2 = df4net2[df4net2['weight_scale'] > corr_cutoff]

positive_cutoff = 0.5
negative_corr = -0.5
df4net_pos = df4net_tmp[df4net_tmp['value'] > positive_cutoff]
df4net_neg = df4net_tmp[df4net_tmp['value'] < negative_corr]

df4net2 = pd.concat([df4net_pos, df4net_neg], axis=0)

from sklearn.preprocessing import MinMaxScaler  

scaler = MinMaxScaler(feature_range=(0, 0.99))  
df4net2['weight_scale2'] = scaler.fit_transform(df4net2['weight_scale'].values.reshape(-1, 1)).flatten()  
df4net2

ax = sns.kdeplot(df4net2['value'])
ax.set_title(f'pos (corr) cutoff {positive_cutoff}\n neg cf({0.5}) ')
df4net2.shape
# Out:
#                  idid     celltype     value  weight_scale
# 59   C10_CD8_Trm_GZMB  C10_Fib_HSP -0.237870      0.237870
# 118  C10_CD8_Trm_GZMB  C11_CD8_Tex  0.659228      0.659228
# (315, 5)

# %%
df4net2.query('value<0').shape
# Out:
# (87, 5)

# %%
def network_G_pos(df_p):
    G = nx.Graph()
    G.clear()

    nodes = pd.DataFrame(list(set(pd.concat([df_p["idid"], df_p["celltype"]], axis=0))))
    nodes.index = range(nodes.shape[0])
    nodes.columns = ['node']

    for i, row in nodes.iterrows():
        G.add_node(row['node'])

    for i, row in df_p.iterrows():
        G.add_edge(row['idid'], row['celltype'], weight=row['value'], length=row['value'])

    return nodes, G


nodes, G = network_G_pos(df4net2)

# %%
fig, ax = plt.subplots(figsize=(7,5.7))
prog = ['dot', 'twopi', 'sfdp', 'circo', 'fdp']
pos = nx.nx_agraph.graphviz_layout(G, prog=prog[4])

edge_list_plus_corr = [(row['idid'], row['celltype']) for i, row in df4net2.query('value>0').iterrows()]
edge_list_minus_corr = [(row['idid'], row['celltype']) for i, row in df4net2.query('value<0').iterrows()]


edges_plus_corr = nx.draw_networkx_edges(G, pos, 
                       edgelist=edge_list_plus_corr,
                       #edge_color=df4net2.query('value>0')['value'], 
                       width=df4net2.query('value>0')['weight_scale2']*5,
                       #width=2,
                       ax=ax,
                       alpha=df4net2.query('value>0')['weight_scale2'].to_list(),
                       edge_color='#DD5778',
                       style = 'solid')

edges_minus_corr = nx.draw_networkx_edges(G, pos, 
                       edgelist=edge_list_minus_corr,
                       #edge_color=df4net2.query('value<0')['value'], 
                       width=df4net2.query('value<0')['weight_scale2']*5,
                       #width=2,
                       ax=ax,
                       #alpha=df4net2.query('value<0')['weight_scale'].to_list(),
                       edge_color='#45ADD6',
                       style = 'solid')


for i,row in nodes.iterrows():
    nx.draw_networkx_nodes(G, pos, 
                           nodelist=[row['node']], 
                           node_size=120,
                           node_color=aaa.loc[ row['node'],'color'],
                           #alpha=0.5
                          )
 
bbox={'facecolor': 'None', #填充色
      'edgecolor': 'None',#外框色
      'alpha': 0.5, #框透明度
      'pad': 0,#本文与框周围距离
     }
    
#props = dict(boxstyle='round', facecolor='white', alpha=0.5)
props = dict(fontweight='bold')
labels = {i:i.split('_')[0] for i in pos}

labels = nx.draw_networkx_labels(G, pos, labels=labels, font_size=6, font_color='w', bbox=bbox)



############################### add legend
for i,row in aaa[['type', 'color']].drop_duplicates().iterrows():
    ax.scatter(None,None, label=row['type'], color=row['color'])
ax.legend(title='CellType', bbox_to_anchor=(1, 0.7), loc=2, frameon=False)

########### legend 2
axin1 = ax.inset_axes([0, 0, 1, 1])
axin1.set_facecolor('none')

axin1.plot(0,0, label='Positive', color='#DD5778', alpha=1)
axin1.plot(0,0, label='Negative', color='#45ADD6', alpha=1)

axin1.legend(title='Correlation', bbox_to_anchor=(1, 1), loc=2, frameon=False)
axin1.set_axis_off()



########### legend 3
ax2 = ax.twinx()
lg_list = scaler.fit_transform(np.array([df4net2['weight_scale'].describe()['min'], 
                               df4net2['weight_scale'].describe()['max'], 
                               0.6, 
                               0.8, 
                               0.9]).reshape(-1, 1)).flatten()  

ax2.plot(0,0, label='0.6', color='black', alpha=1, linewidth=lg_list[2]*5)
ax2.plot(0,0, label='0.8', color='black', alpha=1, linewidth=lg_list[3]*5)
ax2.plot(0,0, label='0.9', color='black', alpha=1, linewidth=lg_list[4]*5)
ax2.legend(title='Abs(Cor)', bbox_to_anchor=(1, 0.87), loc=2, frameon=False)
ax2.set(yticklabels=[], yticks=[])
ax.set(yticklabels=[], yticks=[])



#plt.axis("off")
plt.tight_layout()

plt.savefig(f'{Tissue}_network_cell_fraction2.pdf')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /pmo/anaconda2023/lib/python3.10/site-packages/networkx/drawing/nx_agraph.py:284, in pygraphviz_layout(G, prog, root, args)
#     283 try:
# --> 284     import pygraphviz
#     285 except ImportError as err:
#
# ModuleNotFoundError: No module named 'pygraphviz'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[41], line 3
#       1 fig, ax = plt.subplots(figsize=(7,5.7))
#       2 prog = ['dot', 'twopi', 'sfdp', 'circo', 'fdp']
# ----> 3 pos = nx.nx_agraph.graphviz_layout(G, prog=prog[4])
#       5 edge_list_plus_corr = [(row['idid'], row['celltype']) for i, row in df4net2.query('value>0').iterrows()]
#       6 edge_list_minus_corr = [(row['idid'], row['celltype']) for i, row in df4net2.query('value<0').iterrows()]
#
# File /pmo/anaconda2023/lib/python3.10/site-packages/networkx/drawing/nx_agraph.py:242, in graphviz_layout(G, prog, root, args)
#     214 def graphviz_layout(G, prog="neato", root=None, args=""):
#     215     """Create node positions for G using Graphviz.
#     216
#     217     Parameters
#    (...)
#     240     This is a wrapper for pygraphviz_layout.
#     241     """
# --> 242     return pygraphviz_layout(G, prog=prog, root=root, args=args)
#
# File /pmo/anaconda2023/lib/python3.10/site-packages/networkx/drawing/nx_agraph.py:286, in pygraphviz_layout(G, prog, root, args)
#     284     import pygraphviz
#     285 except ImportError as err:
# --> 286     raise ImportError(
#     287         "requires pygraphviz " "http://pygraphviz.github.io/"
#     288     ) from err
#     289 if root is not None:
#     290     args += f"-Groot={root}"
#
# ImportError: requires pygraphviz http://pygraphviz.github.io/
