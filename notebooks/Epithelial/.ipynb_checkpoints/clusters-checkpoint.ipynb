# %% [markdown]
# # Epithelial clusters

# %% [markdown]
# ## 各亚群umap分布

# %% [markdown]
# ![image.png](attachment:29909f64-2ea9-4ffd-885d-f29b4f86d0ff.png)
# ### 交付
# *  交付单号
# XXXXX
# * 文件路径
# XXXX/AA/aa.pdf

# %% [markdown]
# ## 各亚群占比统计分析

# %% [markdown]
# ![image.png](attachment:d4bd539e-84c1-4e64-949a-bb5c9de1aef1.png)
# ### 交付
# *  交付单号
# XXXXX
# * 文件路径
# XXXX/AA/aa.pdf
